# %%
import os
import numpy as np
import pandas as pd

# %%
header_2024 = ['lastname', 'firstname', 'middlename', 'namesuffix', 'raddnumber', 
               'rhalfcode', 
               'rpredirection', 'rstreetname', 'rpostdirection', 
               'rapartmenttype', 'rapartment', 'raddrnonstd', 
               'rcity', 'rzip5', 'rzip4', 'mailadd1', 'mailadd2', 
               'mailadd3', 'mailadd4', 'dob', 'gender', 'enrollment', 'otherparty', 'countycode', 
               'ed', 'ld', 'towncity', 'ward', 'cd', 'sd', 'ad', 'lastvoteddate', 'prevyearvoted', 
               'prevcounty', 'prevaddress', 'prevname', 'countyvrnumber', 'regdate', 'vrsource', 
               'idrequired', 'idmet', 'status', 'reasoncode', 'inact_date', 'purge_date', 'sboeid', 'voterhistory']

df = pd.read_csv('AllNYSVoters_20240529.csv',
                sep=',',
                names = header_2024,
                encoding='ISO-8859-1',
                low_memory= False             # Alternative encoding
                )
df.head()
# Out:
#     lastname firstname middlename namesuffix raddnumber rhalfcode  \
# 0     STEILS     BRIAN          S        NaN       6312       NaN
# 1   JEFFORDS      RYAN          D        NaN       1408       NaN
# 2  OSTROWSKI    JENNIE          M        NaN       7011       NaN
# 3    KINDZIA     JULIE          D        NaN        507       NaN
# 4     MARTIN     ANDRE        NaN        NaN        538       NaN
#
#   rpredirection       rstreetname rpostdirection rapartmenttype  ...  \
# 0           NaN  GREEN VALLEY LN             NaN            NaN  ...
# 1           NaN     ELDERBERRY PL            NaN            NaN  ...
# 2           NaN        MONROE ST             NaN            NaN  ...
# 3           NaN          87TH ST             NaN            NaN  ...
# 4           NaN        PORTAGE RD            NaN            NaN  ...
#
#       regdate vrsource idrequired  idmet status reasoncode  inact_date  \
# 0  19900607.0     CBOE          N      Y      A        NaN         NaN
# 1  19910115.0     CBOE          N      Y      I       NCOA  20220211.0
# 2  19931202.0     CBOE          N      Y      A        NaN         NaN
# 3  19961209.0     CBOE          N      Y      A        NaN         NaN
# 4  19960524.0     CBOE          N      Y      A        NaN         NaN
#
#   purge_date                sboeid  \
# 0        NaN  NY000000000003306195
# 1        NaN  NY000000000003306196
# 2        NaN  NY000000000003306198
# 3        NaN  NY000000000003306199
# 4        NaN  NY000000000003306201
#
#                                         voterhistory
# 0                                                NaN
# 1                                                NaN
# 2  2022 General Election(P);2022 Primary Election...
# 3                                                NaN
# 4  2023 General Election(P);2020 General Election...
#
# [5 rows x 47 columns]

# %%
# change the order of columns - 2024
new_order = ['lastname', 'firstname', 'middlename', 'namesuffix', 'raddnumber', 
            'rhalfcode', 
            'rapartment', 
            'rpredirection', 'rstreetname', 'rpostdirection', 
            'rcity', 'rzip5', 'rzip4', 'mailadd1', 'mailadd2', 
            'mailadd3', 'mailadd4', 'dob', 'gender', 'enrollment', 'otherparty', 'countycode', 
            'ed', 'ld', 'towncity', 'ward', 'cd', 'sd', 'ad', 'lastvoteddate', 'prevyearvoted', 
            'prevcounty', 'prevaddress', 'prevname', 'countyvrnumber', 'regdate', 'vrsource', 
            'idrequired', 'idmet', 'status', 'reasoncode', 'inact_date', 'purge_date', 'sboeid', 'voterhistory', 
            'rapartmenttype', 'raddrnonstd', ]

df_24_reordered = df[new_order]
df_24_reordered.head()
# Out:
#     lastname firstname middlename namesuffix raddnumber rhalfcode rapartment  \
# 0     STEILS     BRIAN          S        NaN       6312       NaN        NaN
# 1   JEFFORDS      RYAN          D        NaN       1408       NaN        NaN
# 2  OSTROWSKI    JENNIE          M        NaN       7011       NaN        NaN
# 3    KINDZIA     JULIE          D        NaN        507       NaN        NaN
# 4     MARTIN     ANDRE        NaN        NaN        538       NaN        NaN
#
#   rpredirection       rstreetname rpostdirection  ... idrequired  idmet  \
# 0           NaN  GREEN VALLEY LN             NaN  ...          N      Y
# 1           NaN     ELDERBERRY PL            NaN  ...          N      Y
# 2           NaN        MONROE ST             NaN  ...          N      Y
# 3           NaN          87TH ST             NaN  ...          N      Y
# 4           NaN        PORTAGE RD            NaN  ...          N      Y
#
#   status reasoncode  inact_date purge_date                sboeid  \
# 0      A        NaN         NaN        NaN  NY000000000003306195
# 1      I       NCOA  20220211.0        NaN  NY000000000003306196
# 2      A        NaN         NaN        NaN  NY000000000003306198
# 3      A        NaN         NaN        NaN  NY000000000003306199
# 4      A        NaN         NaN        NaN  NY000000000003306201
#
#                                         voterhistory rapartmenttype  \
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2  2022 General Election(P);2022 Primary Election...            NaN
# 3                                                NaN            NaN
# 4  2023 General Election(P);2020 General Election...            NaN
#
#   raddrnonstd
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 47 columns]

# %%
header_2020 = ['lastname', 'firstname', 'middlename', 'namesuffix', 'raddnumber', 
               'rhalfcode', 
               'rapartment', 
               'rpredirection', 'rstreetname', 'rpostdirection', 
               'rcity', 'rzip5', 'rzip4', 'mailadd1', 'mailadd2', 'mailadd3', 'mailadd4', 
               'dob', 'gender', 'enrollment', 'otherparty', 'countycode', 'ed', 'ld', 'towncity',
               'ward', 'cd', 'sd', 'ad', 'lastvoteddate', 'prevyearvoted', 'prevcounty', 
               'prevaddress', 'prevname', 'countyvrnumber', 'regdate', 'vrsource', 'idrequired', 
               'idmet', 'status', 'reasoncode', 'inact_date', 'purge_date', 'sboeid', 'voterhistory']

df_2020 = pd.read_csv('AllNYSVoters_20201116.txt', 
                    sep=',', 
                    encoding='latin-1',
                    low_memory= False,
                    names = header_2020)
df_2020.head()
# Out:
#     lastname firstname middlename namesuffix raddnumber rhalfcode rapartment  \
# 0     SEXTON   COLLEEN          M        NaN        703       NaN        NaN
# 1     STEILS     BRIAN          S        NaN       6312       NaN        NaN
# 2   JEFFORDS      RYAN          D        NaN       1408       NaN        NaN
# 3    SINDONI   ANTHONY          M        NaN       9257       NaN        NaN
# 4  OSTROWSKI    JENNIE          M        NaN       7011       NaN        NaN
#
#   rpredirection       rstreetname rpostdirection  ...   regdate  vrsource  \
# 0           NaN     WURLITZER DR             NaN  ...  19890413      CBOE
# 1           NaN  GREEN VALLEY LN             NaN  ...  19900607      CBOE
# 2           NaN    ELDERBERRY PL             NaN  ...  19910115       DMV
# 3           NaN       COLEMAN RD             NaN  ...  19930226      MAIL
# 4           NaN        MONROE ST             NaN  ...  19931202      CBOE
#
#    idrequired idmet    status reasoncode  inact_date  purge_date  \
# 0           N     Y    PURGED      MOVED         NaN  20140611.0
# 1           N     Y    ACTIVE        NaN         NaN         NaN
# 2           N     Y    ACTIVE        NaN         NaN         NaN
# 3           N     Y  INACTIVE  MAILCHECK  20150805.0         NaN
# 4           N     Y    ACTIVE        NaN         NaN         NaN
#
#                  sboeid                                       voterhistory
# 0  NY000000000003306194  2012 General Election;2010 General Election;20...
# 1  NY000000000003306195                                                NaN
# 2  NY000000000003306196                                                NaN
# 3  NY000000000003306197  2012 General Election;2012 Presidential Primar...
# 4  NY000000000003306198  2020 General Election;2019 General Election;20...
#
# [5 rows x 45 columns]

# %%
# add 2 columns to match 2024
df_2020['rapartmenttype'] = np.nan
df_2020['raddrnonstd'] = np.nan

df_2020.head()
# Out:
#     lastname firstname middlename namesuffix raddnumber rhalfcode rapartment  \
# 0     SEXTON   COLLEEN          M        NaN        703       NaN        NaN
# 1     STEILS     BRIAN          S        NaN       6312       NaN        NaN
# 2   JEFFORDS      RYAN          D        NaN       1408       NaN        NaN
# 3    SINDONI   ANTHONY          M        NaN       9257       NaN        NaN
# 4  OSTROWSKI    JENNIE          M        NaN       7011       NaN        NaN
#
#   rpredirection       rstreetname rpostdirection  ... idrequired  idmet  \
# 0           NaN     WURLITZER DR             NaN  ...          N      Y
# 1           NaN  GREEN VALLEY LN             NaN  ...          N      Y
# 2           NaN    ELDERBERRY PL             NaN  ...          N      Y
# 3           NaN       COLEMAN RD             NaN  ...          N      Y
# 4           NaN        MONROE ST             NaN  ...          N      Y
#
#      status reasoncode  inact_date  purge_date                sboeid  \
# 0    PURGED      MOVED         NaN  20140611.0  NY000000000003306194
# 1    ACTIVE        NaN         NaN         NaN  NY000000000003306195
# 2    ACTIVE        NaN         NaN         NaN  NY000000000003306196
# 3  INACTIVE  MAILCHECK  20150805.0         NaN  NY000000000003306197
# 4    ACTIVE        NaN         NaN         NaN  NY000000000003306198
#
#                                         voterhistory rapartmenttype  \
# 0  2012 General Election;2010 General Election;20...            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3  2012 General Election;2012 Presidential Primar...            NaN
# 4  2020 General Election;2019 General Election;20...            NaN
#
#   raddrnonstd
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 47 columns]

# %%
# merging them together

df_20_24 = pd.concat([df_2020, df_24_reordered])
df_20_24.tail()
# Out:
#                    lastname   firstname middlename namesuffix raddnumber  \
# 13265594            MORALES       GYSEL        NaN        NaN         27
# 13265595             RIVERA       PAIGE          I        NaN         52
# 13265596           DUROSIER  ALDALOURDE        NaN        NaN        500
# 13265597           THEAGENE      MARCUS          G        NaN          8
# 13265598  FIGUEROA GONZALEZ     BRANDON        NaN        NaN         12
#
#          rhalfcode rapartment rpredirection    rstreetname rpostdirection  \
# 13265594       NaN          B           NaN  W FUNSTON AVE            NaN
# 13265595       NaN        NaN           NaN   PINEBROOK RD            NaN
# 13265596       NaN         61           NaN  E FUNSTON AVE            NaN
# 13265597       NaN        NaN           NaN      TURNER CT            NaN
# 13265598       NaN        NaN           NaN     PAULINE CT            NaN
#
#           ... idrequired  idmet status reasoncode inact_date purge_date  \
# 13265594  ...          N      Y     17        NaN        NaN        NaN
# 13265595  ...          N      Y     17        NaN        NaN        NaN
# 13265596  ...          N      Y     17        NaN        NaN        NaN
# 13265597  ...          N      Y     17        NaN        NaN        NaN
# 13265598  ...          N      Y     17        NaN        NaN        NaN
#
#                         sboeid  voterhistory rapartmenttype raddrnonstd
# 13265594  NY000000000063652443           NaN            APT         NaN
# 13265595  NY000000000063652444           NaN            NaN         NaN
# 13265596  NY000000000063652445           NaN            APT         NaN
# 13265597  NY000000000063652447           NaN            NaN         NaN
# 13265598  NY000000000063652446           NaN            NaN         NaN
#
# [5 rows x 47 columns]

# %%
len(df_2020) + len(df_24_reordered)

# 2020: 20179326
# 2024: 13265599
# Out:
# 33444925

# %%
len(df_20_24)
# Out:
# 33444925

# %%
# reorder the columns to the original order

old_order = ['lastname', 'firstname', 'middlename', 'namesuffix', 'raddnumber', 
               'rhalfcode', 
               'rpredirection', 'rstreetname', 'rpostdirection', 
               'rapartmenttype', 'rapartment', 'raddrnonstd', 
               'rcity', 'rzip5', 'rzip4', 'mailadd1', 'mailadd2', 
               'mailadd3', 'mailadd4', 'dob', 'gender', 'enrollment', 'otherparty', 'countycode', 
               'ed', 'ld', 'towncity', 'ward', 'cd', 'sd', 'ad', 'lastvoteddate', 'prevyearvoted', 
               'prevcounty', 'prevaddress', 'prevname', 'countyvrnumber', 'regdate', 'vrsource', 
               'idrequired', 'idmet', 'status', 'reasoncode', 'inact_date', 'purge_date', 'sboeid', 'voterhistory']

df_20_24_comb = df_20_24[old_order]
df_20_24_comb.head()
# Out:
#     lastname firstname middlename namesuffix raddnumber rhalfcode  \
# 0     SEXTON   COLLEEN          M        NaN        703       NaN
# 1     STEILS     BRIAN          S        NaN       6312       NaN
# 2   JEFFORDS      RYAN          D        NaN       1408       NaN
# 3    SINDONI   ANTHONY          M        NaN       9257       NaN
# 4  OSTROWSKI    JENNIE          M        NaN       7011       NaN
#
#   rpredirection       rstreetname rpostdirection rapartmenttype  ...  \
# 0           NaN     WURLITZER DR             NaN            NaN  ...
# 1           NaN  GREEN VALLEY LN             NaN            NaN  ...
# 2           NaN    ELDERBERRY PL             NaN            NaN  ...
# 3           NaN       COLEMAN RD             NaN            NaN  ...
# 4           NaN        MONROE ST             NaN            NaN  ...
#
#       regdate vrsource idrequired  idmet    status reasoncode  inact_date  \
# 0  19890413.0     CBOE          N      Y    PURGED      MOVED         NaN
# 1  19900607.0     CBOE          N      Y    ACTIVE        NaN         NaN
# 2  19910115.0      DMV          N      Y    ACTIVE        NaN         NaN
# 3  19930226.0     MAIL          N      Y  INACTIVE  MAILCHECK  20150805.0
# 4  19931202.0     CBOE          N      Y    ACTIVE        NaN         NaN
#
#    purge_date                sboeid  \
# 0  20140611.0  NY000000000003306194
# 1         NaN  NY000000000003306195
# 2         NaN  NY000000000003306196
# 3         NaN  NY000000000003306197
# 4         NaN  NY000000000003306198
#
#                                         voterhistory
# 0  2012 General Election;2010 General Election;20...
# 1                                                NaN
# 2                                                NaN
# 3  2012 General Election;2012 Presidential Primar...
# 4  2020 General Election;2019 General Election;20...
#
# [5 rows x 47 columns]

# %%
# df_20_24_comb.to_csv('merged_voter_data_20_24.csv', encoding='utf-8', index=False)

# %%
# the only duplicate row

# %%
duplicates = df_20_24_comb.duplicated()

# %%
num_duplicates = duplicates.sum()
print(num_duplicates)

duplicate_rows = df_20_24_comb[duplicates].isna()
print(duplicate_rows)
# Out:
# 1
#          lastname firstname middlename namesuffix raddnumber rhalfcode  \
# 13265554      NaN       NaN        NaN        NaN        NaN       NaN
#
#          rpredirection rstreetname rpostdirection rapartmenttype  ... regdate  \
# 13265554           NaN         NaN            NaN            NaN  ...     NaN
#
#          vrsource idrequired  idmet status reasoncode inact_date purge_date  \
# 13265554      NaN        NaN    NaN    NaN        NaN        NaN        NaN
#
#          sboeid  voterhistory
# 13265554    NaN           NaN
#
# [1 rows x 47 columns]

# %%
duplicates = df_24_reordered.duplicated()

# %%
num_duplicates = duplicates.sum()
print(num_duplicates)

duplicate_rows = df_24_reordered[duplicates].isna()
print(duplicate_rows)
# Out:
# 1
#           lastname  firstname  middlename  namesuffix  raddnumber  rhalfcode  \
# 13265554      True       True        True        True        True       True
#
#           rapartment  rpredirection  rstreetname  rpostdirection  ...  \
# 13265554        True           True         True            True  ...
#
#           idrequired  idmet  status  reasoncode  inact_date  purge_date  \
# 13265554        True   True    True        True        True        True
#
#           sboeid  voterhistory  rapartmenttype  raddrnonstd
# 13265554    True          True            True         True
#
# [1 rows x 47 columns]

# %%
# expect a large number of null values
